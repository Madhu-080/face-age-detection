# %%
import cv2

# Load pre-trained face detection model
face_net = cv2.dnn.readNetFromCaffe(
    'models/deploy.prototxt',
    'models/res10_300x300_ssd_iter_140000.caffemodel'
)
image_path = r"C:\Users\MADHU\OneDrive\Desktop\photo.jpg"
# Load image
image = cv2.imread(image_path)  # Replace with your image path
(h, w) = image.shape[:2]

# Prepare input blob for the model
blob = cv2.dnn.blobFromImage(
    cv2.resize(image, (300, 300)),
    1.0,
    (300, 300),
    (104.0, 177.0, 123.0)
)
face_net.setInput(blob)
detections = face_net.forward()

# Draw bounding boxes
for i in range(detections.shape[2]):
    confidence = detections[0, 0, i, 2]

    if confidence > 0.5:
        box = detections[0, 0, i, 3:7] * [w, h, w, h]
        (startX, startY, endX, endY) = box.astype("int")
        cv2.rectangle(image, (startX, startY), (endX, endY), (0, 255, 0), 2)
        label = f"Face: {confidence*100:.2f}%"
        cv2.putText(image, label, (startX, startY - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 255, 0), 2)

# Show result
cv2.imshow("Detected Faces", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[4], line 36
#      32         cv2.putText(image, label, (startX, startY - 10),
#      33                     cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 255, 0), 2)
#      35 # Show result
# ---> 36 cv2.imshow("Detected Faces", image)
#      37 cv2.waitKey(0)
#      38 cv2.destroyAllWindows()
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1301: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'

# %%
import cv2
import matplotlib.pyplot as plt

# Load pre-trained face detection model
face_net = cv2.dnn.readNetFromCaffe(
    'models/deploy.prototxt',
    'models/res10_300x300_ssd_iter_140000.caffemodel'
)

# Load image
image_path = r"C:\Users\MADHU\OneDrive\Desktop\photo.jpg"
image = cv2.imread(image_path)  # BGR image
(h, w) = image.shape[:2]

# Prepare input blob for the model
blob = cv2.dnn.blobFromImage(
    cv2.resize(image, (300, 300)),
    1.0,
    (300, 300),
    (104.0, 177.0, 123.0)
)
face_net.setInput(blob)
detections = face_net.forward()

# Draw bounding boxes
for i in range(detections.shape[2]):
    confidence = detections[0, 0, i, 2]

    if confidence > 0.5:
        box = detections[0, 0, i, 3:7] * [w, h, w, h]
        (startX, startY, endX, endY) = box.astype("int")
        cv2.rectangle(image, (startX, startY), (endX, endY), (0, 255, 0), 2)
        label = f"Face: {confidence*100:.2f}%"
        cv2.putText(image, label, (startX, startY - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 255, 0), 2)

# Convert BGR (OpenCV) to RGB (matplotlib)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display using matplotlib
plt.figure(figsize=(8, 6))
plt.imshow(image_rgb)
plt.axis('off')
plt.title("Detected Faces")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Load pre-trained face detection model
face_net = cv2.dnn.readNetFromCaffe(
    'models/deploy.prototxt',
    'models/res10_300x300_ssd_iter_140000.caffemodel'
)

# Load image
image_path = r"C:\Users\MADHU\OneDrive\Desktop\photo.jpg"
image = cv2.imread(image_path)  # BGR image
(h, w) = image.shape[:2]

# Prepare input blob for the model
blob = cv2.dnn.blobFromImage(
    cv2.resize(image, (300, 300)),
    1.0,
    (300, 300),
    (104.0, 177.0, 123.0)
)
face_net.setInput(blob)
detections = face_net.forward()
detections[0,0,0]
# Out:
# array([0.        , 1.        , 0.9999939 , 0.31452113, 0.18247488,
#        0.69858783, 0.53800213], dtype=float32)
